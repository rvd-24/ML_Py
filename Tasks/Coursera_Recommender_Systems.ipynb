# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("Coursera.csv")
df.head()
# Out:
#                                          Course Name  \
# 0  Write A Feature Length Screenplay For Film Or ...
# 1  Business Strategy: Business Model Canvas Analy...
# 2                      Silicon Thin Film Solar Cells
# 3                               Finance for Managers
# 4       Retrieve Data using Single-Table SQL Queries
#
#                   University Difficulty Level Course Rating  \
# 0  Michigan State University         Beginner           4.8
# 1   Coursera Project Network         Beginner           4.8
# 2        �cole Polytechnique         Advanced           4.1
# 3       IESE Business School     Intermediate           4.8
# 4   Coursera Project Network         Beginner           4.6
#
#                                           Course URL  \
# 0  https://www.coursera.org/learn/write-a-feature...
# 1  https://www.coursera.org/learn/canvas-analysis...
# 2  https://www.coursera.org/learn/silicon-thin-fi...
# 3  https://www.coursera.org/learn/operational-fin...
# ...

# %%
df['Skills']
# Out:
# 0       Drama  Comedy  peering  screenwriting  film  D...
# 1       Finance  business plan  persona (user experien...
# 2       chemistry  physics  Solar Energy  film  lambda...
# 3       accounts receivable  dupont analysis  analysis...
# 4       Data Analysis  select (sql)  database manageme...
#                               ...
# 3517    Databases  syntax  analysis  web  Data Visuali...
# 3518    retirement  Causality  career  history of the ...
# 3519    analytics  tableau software  Business Intellig...
# 3520    Angular  Mechanical Design  fluid mechanics  F...
# 3521    bigtable  bigquery  SQL  Google Cloud Platform...
# Name: Skills, Length: 3522, dtype: object

# %%
df['Skills'][4]
# Out:
# 'Data Analysis  select (sql)  database management systems  online shopping  table (database)  data retrieval  Databases  web page  numbers (spreadsheet)  SQL information-technology data-management'

# %%
df1=df['Skills'].str.lower().str.split('  ')
df1
# Out:
# 0       [drama, comedy, peering, screenwriting, film, ...
# 1       [finance, business plan, persona (user experie...
# 2       [chemistry, physics, solar energy, film, lambd...
# 3       [accounts receivable, dupont analysis, analysi...
# 4       [data analysis, select (sql), database managem...
#                               ...
# 3517    [databases, syntax, analysis, web, data visual...
# 3518    [retirement, causality, career, history of the...
# 3519    [analytics, tableau software, business intelli...
# 3520    [angular, mechanical design, fluid mechanics, ...
# 3521    [bigtable, bigquery, sql, google cloud platfor...
# Name: Skills, Length: 3522, dtype: object

# %%
df2=set()
for i in df1.iteritems():
    for j in i[1]:
        df2.add(j)
len(df2)
df2=df2

# %%
df2=list(df2)
df2=pd.DataFrame(df2)
df2=df2.iloc[1:,:]
df2
# Out:
#                                                       0
# 1
# 2     communication in small groups social-sciences ...
# 3                                       virtual circuit
# 4                              app inventor for android
# 5                              software incompatibility
# ...                                                 ...
# 8549                                         common law
# 8550                      enterprise information system
# 8551                                    problem finding
# 8552                                   marketing myopia
# 8553                               spreadsheet software
#
# [8553 rows x 1 columns]

# %%
df.Skills.apply(lambda x:pd.value_counts(x.split())).sum(axis=0)
# Out:
# Drama             8.0
# Comedy            5.0
# peering          14.0
# screenwriting     4.0
# film             39.0
#                  ...
# goms              1.0
# sensemaking       1.0
# fcaps             1.0
# retirement        1.0
# rig               1.0
# Length: 5397, dtype: float64

# %%
tg=df['Skills'].str.lower().str.split()
tg[1]
# Out:
# ['finance',
#  'business',
#  'plan',
#  'persona',
#  '(user',
#  'experience)',
#  'business',
#  'model',
#  'canvas',
#  'planning',
#  'business',
#  'project',
#  'product',
#  'development',
#  'presentation',
#  'strategy',
#  'business',
#  'business-strategy']

# %%
lt=set()
for i in range (0,len(tg)):
    for j in range (0,len(tg[i])):
        lt.add(tg[i][j])
lt
# Out:
# {'transpose',
#  'land',
#  'bigtable',
#  'template',
#  'training',
#  'change',
#  'organizations',
#  'library',
#  'decorrelation',
#  'growth',
#  'antivirus',
#  'placement',
#  'meta',
#  'access',
#  'superscalar',
#  'two',
#  'breaches',
#  'kits',
#  'swing',
#  'fallacy',
#  'scratch',
#  'optimism',
#  'hazard',
#  'operation',
#  'proof-of-stake',
#  'rig',
#  'rational',
#  'jmeter',
#  'davis',
#  'public-health',
#  'restore',
#  'return',
#  'lifelong',
#  't.i.m.e.',
#  'women',
#  'intuition',
#  'immutable',
#  'events',
#  'seeks',
#  'stream',
#  'leakage',
#  '(nutrition)',
#  'skewness',
#  'peering',
#  'authorised',
#  'sensitivity',
#  'walking',
#  'voltage',
#  'regression',
#  'threadsafe',
#  'threat',
#  'inkscape',
#  'dance',
#  "porter's",
#  'scraping',
#  'cidn',
#  'elderly',
#  'price',
#  'mod',
#  'subscribe',
#  'phone',
#  'opms',
#  'tool',
#  'cross-sectional',
#  'mobility',
#  'sovereignty',
#  'interview',
#  'phylogenetic',
# ...

# %%
lt=list(lt)
lt=pd.DataFrame(lt)
lt
# Out:
#                 0
# 0       transpose
# 1            land
# 2        bigtable
# 3        template
# 4        training
# ...           ...
# 4754    decoction
# 4755  abstraction
# 4756   electronic
# 4757  elicitation
# 4758  improvement
#
# [4759 rows x 1 columns]

# %%
df2=pd.concat([df,lt.T],axis='columns')
df2.head()
# Out:
#                                          Course Name  \
# 0  Write A Feature Length Screenplay For Film Or ...
# 1  Business Strategy: Business Model Canvas Analy...
# 2                      Silicon Thin Film Solar Cells
# 3                               Finance for Managers
# 4       Retrieve Data using Single-Table SQL Queries
#
#                   University Difficulty Level Course Rating  \
# 0  Michigan State University         Beginner           4.8
# 1   Coursera Project Network         Beginner           4.8
# 2        �cole Polytechnique         Advanced           4.1
# 3       IESE Business School     Intermediate           4.8
# 4   Coursera Project Network         Beginner           4.6
#
#                                           Course URL  \
# 0  https://www.coursera.org/learn/write-a-feature...
# 1  https://www.coursera.org/learn/canvas-analysis...
# 2  https://www.coursera.org/learn/silicon-thin-fi...
# 3  https://www.coursera.org/learn/operational-fin...
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df['label']=le.fit_transform(df['lt'])

# %%
df.label.unique()
# Out:
# array([ 387,  444, 1345, ..., 1129,   56, 1239])

# %%
df.label.shape
# Out:
# (3522,)

# %%
df.isnull().sum()
df.head()
# Out:
#                                          Course Name  \
# 0  Write A Feature Length Screenplay For Film Or ...
# 1  Business Strategy: Business Model Canvas Analy...
# 2                      Silicon Thin Film Solar Cells
# 3                               Finance for Managers
# 4       Retrieve Data using Single-Table SQL Queries
#
#                   University Difficulty Level Course Rating  \
# 0  Michigan State University         Beginner           4.8
# 1   Coursera Project Network         Beginner           4.8
# 2        �cole Polytechnique         Advanced           4.1
# 3       IESE Business School     Intermediate           4.8
# 4   Coursera Project Network         Beginner           4.6
#
#                                           Course URL  \
# 0  https://www.coursera.org/learn/write-a-feature...
# 1  https://www.coursera.org/learn/canvas-analysis...
# 2  https://www.coursera.org/learn/silicon-thin-fi...
# 3  https://www.coursera.org/learn/operational-fin...
# ...

# %%
x=df['Course Rating'].str.contains('Not Calibrated')
x.value_counts()
# Out:
# False    3440
# True       82
# Name: Course Rating, dtype: int64

# %%
inputs=df
inputs.head()
# Out:
#                                          Course Name  \
# 0  Write A Feature Length Screenplay For Film Or ...
# 1  Business Strategy: Business Model Canvas Analy...
# 2                      Silicon Thin Film Solar Cells
# 3                               Finance for Managers
# 4       Retrieve Data using Single-Table SQL Queries
#
#                   University Difficulty Level Course Rating  \
# 0  Michigan State University         Beginner           4.8
# 1   Coursera Project Network         Beginner           4.8
# 2        �cole Polytechnique         Advanced           4.1
# 3       IESE Business School     Intermediate           4.8
# 4   Coursera Project Network         Beginner           4.6
#
#                                           Course URL  \
# 0  https://www.coursera.org/learn/write-a-feature...
# 1  https://www.coursera.org/learn/canvas-analysis...
# 2  https://www.coursera.org/learn/silicon-thin-fi...
# 3  https://www.coursera.org/learn/operational-fin...
# ...

# %%
inputs['Skills']=inputs['Skills'].str.lower().str.split()

# %%
inputs.head()
# Out:
#                                          Course Name  \
# 0  Write A Feature Length Screenplay For Film Or ...
# 1  Business Strategy: Business Model Canvas Analy...
# 2                      Silicon Thin Film Solar Cells
# 3                               Finance for Managers
# 4       Retrieve Data using Single-Table SQL Queries
#
#                   University Difficulty Level Course Rating  \
# 0  Michigan State University         Beginner           4.8
# 1   Coursera Project Network         Beginner           4.8
# 2        �cole Polytechnique         Advanced           4.1
# 3       IESE Business School     Intermediate           4.8
# 4   Coursera Project Network         Beginner           4.6
#
#                                           Course URL  \
# 0  https://www.coursera.org/learn/write-a-feature...
# 1  https://www.coursera.org/learn/canvas-analysis...
# 2  https://www.coursera.org/learn/silicon-thin-fi...
# 3  https://www.coursera.org/learn/operational-fin...
# ...

# %%
inputs=inputs.drop(['University','Course URL','Course Description'],axis='columns')

# %%
inputs.head()
# Out:
#                                          Course Name Difficulty Level  \
# 0  Write A Feature Length Screenplay For Film Or ...         Beginner
# 1  Business Strategy: Business Model Canvas Analy...         Beginner
# 2                      Silicon Thin Film Solar Cells         Advanced
# 3                               Finance for Managers     Intermediate
# 4       Retrieve Data using Single-Table SQL Queries         Beginner
#
#   Course Rating                                             Skills  label
# 0           4.8  [drama, comedy, peering, screenwriting, film, ...    387
# 1           4.8  [finance, business, plan, persona, (user, expe...    444
# 2           4.1  [chemistry, physics, solar, energy, film, lamb...   1345
# 3           4.8  [accounts, receivable, dupont, analysis, analy...   1041
# 4           4.6  [data, analysis, select, (sql), database, mana...    321

# %%
tests=df
tests.head()
# Out:
#                                          Course Name  \
# 0  Write A Feature Length Screenplay For Film Or ...
# 1  Business Strategy: Business Model Canvas Analy...
# 2                      Silicon Thin Film Solar Cells
# 3                               Finance for Managers
# 4       Retrieve Data using Single-Table SQL Queries
#
#                   University Difficulty Level Course Rating  \
# 0  Michigan State University         Beginner           4.8
# 1   Coursera Project Network         Beginner           4.8
# 2        �cole Polytechnique         Advanced           4.1
# 3       IESE Business School     Intermediate           4.8
# 4   Coursera Project Network         Beginner           4.6
#
#                                           Course URL  \
# 0  https://www.coursera.org/learn/write-a-feature...
# 1  https://www.coursera.org/learn/canvas-analysis...
# 2  https://www.coursera.org/learn/silicon-thin-fi...
# 3  https://www.coursera.org/learn/operational-fin...
# ...
